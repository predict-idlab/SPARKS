# %%
import pandas as pd
import parseSTL

# %%
with open("/Users/bsteenwi/Documents/volvo/editor/OB1.AWL.txt", 'r') as f:
    file = f.read()#cgi.FieldStorage()['param'].value
data = parseSTL.run(file)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
data['OB1'].networks[0].outs
# Out:
# {'M16.0', 'M16.2'}

# %%
data['OB1'].networks[0].ins
# Out:
# {'I0.0', 'I0.1', 'I0.3', 'M16.1', 'M16.2'}

# %%
data['OB1'].networks[1].outs
# Out:
# {'M16.3', 'Q0.6'}

# %%
data['OB1'].networks[1].ins
# Out:
# {'I0.0', 'I0.1', 'I0.5', 'I0.6', 'M16.1', 'M16.3'}
